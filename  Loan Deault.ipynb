# %%
import numpy as np
import pandas as pd

# %%
loan_df = pd.read_csv(r"C:\Users\M.Srimanth\Downloads\Loan_default.csv\Loan_default.csv")

# %%
loan_df
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
loan_df.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
loan_df.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
loan_df.duplicated().sum()
# Out:
# 0

# %%
loan_df.groupby(['LoanPurpose'])['LoanAmount'].mean()
# Out:
# LoanPurpose
# Auto         127857.908721
# Business     127141.807458
# Education    127645.822841
# Home         127622.382853
# Other        127629.648054
# Name: LoanAmount, dtype: float64

# %%
import seaborn as sns

# %%
sns.barplot(x = ['LoanPurpose'],y = ['LoanAmount'])
# Out:
# <Axes: >

# %%
sns.histplot(x = loan_df['LoanPurpose'],y = loan_df['LoanAmount'])
# Out:
# <Axes: xlabel='LoanPurpose', ylabel='LoanAmount'>

# %%
df['LoanAmount'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df['LoanAmount'].unique()
#
# NameError: name 'df' is not defined

# %%
loan_df.groupby(['LoanPurpose'])['Default'].sum()
# Out:
# LoanPurpose
# Auto         6041
# Business     6323
# Education    6038
# Home         5249
# Other        6002
# Name: Default, dtype: int64

# %%
bool(1)
# Out:
# True

# %%
loan_df.groupby(['LoanPurpose'])['NumCreditLines'].sum()
# Out:
# LoanPurpose
# Auto         126917
# Business     128411
# Education    127798
# Home         128310
# Other        127196
# Name: NumCreditLines, dtype: int64

# %%
loan_df.groupby(['MaritalStatus'])['LoanAmount'].mean()
# Out:
# MaritalStatus
# Divorced    127810.225265
# Married     127250.951326
# Single      127676.481403
# Name: LoanAmount, dtype: float64

# %%
loan_df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     85302
# Divorced    85033
# Single      85012
# Name: count, dtype: int64

# %%
sns.pieplot(loan_df['MaritalStatus'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.pieplot(loan_df['MaritalStatus'])
#
# AttributeError: module 'seaborn' has no attribute 'pieplot'

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(loan_df['MaritalStatus'],
labels = loan_df['MaritalStatus'].value_counts())
plt.title =('MaritalStatus')

# %%
loan_df['MaritalStatus'].value_counts().plot(kind = 'pie',colors=['#E0DDCF','#2D232E','#6494AA'])
# Out:
# <Axes: ylabel='count'>

# %%
loan_df
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
loan_df['Education'].unique()
# Out:
# array(["Bachelor's", "Master's", 'High School', 'PhD'], dtype=object)

# %%
loan_df['Education'].value_counts()
# Out:
# Education
# Bachelor's     64366
# High School    63903
# Master's       63541
# PhD            63537
# Name: count, dtype: int64

# %%
loan_df['Education'].value_counts().plot(kind = 'pie',colors=['#29335C','#F3A712','#534D41','#F0CEA0'])
# Out:
# <Axes: ylabel='count'>

# %%
loan_df.groupby(['Education'])['Income'].mean()
# Out:
# Education
# Bachelor's     82580.142622
# High School    82294.182949
# Master's       82835.208936
# PhD            82287.789587
# Name: Income, dtype: float64

# %%
loan_df.groupby(['Education'])['EmploymentType'].value_counts()
# Out:
# Education    EmploymentType
# Bachelor's   Part-time         16363
#              Unemployed        16120
#              Self-employed     15944
#              Full-time         15939
# High School  Full-time         15993
#              Self-employed     15991
#              Unemployed        15990
#              Part-time         15929
# Master's     Full-time         15978
#              Self-employed     15921
#              Part-time         15867
#              Unemployed        15775
# PhD          Part-time         16002
#              Unemployed        15939
#              Self-employed     15850
#              Full-time         15746
# Name: count, dtype: int64

# %%
loan_df.groupby(['Education'])['LoanAmount'].mean()
# Out:
# Education
# Bachelor's     127390.632026
# High School    127393.676823
# Master's       127710.986450
# PhD            127823.681178
# Name: LoanAmount, dtype: float64

# %%
loan_df.groupby(['Education'])['Default'].sum()
# Out:
# Education
# Bachelor's     7789
# High School    8230
# Master's       6908
# PhD            6726
# Name: Default, dtype: int64

# %%
loan_df.groupby(['Education'])['LoanPurpose'].value_counts()
# Out:
# Education    LoanPurpose
# Bachelor's   Education      13006
#              Business       12973
#              Other          12912
#              Home           12903
#              Auto           12572
# High School  Home           12854
#              Business       12801
#              Other          12777
#              Auto           12748
#              Education      12723
# Master's     Auto           12827
#              Business       12813
#              Home           12756
#              Other          12586
#              Education      12559
# PhD          Home           12773
#              Education      12717
#              Business       12711
#              Auto           12697
#              Other          12639
# Name: count, dtype: int64

# %%
loan_df['LoanAmount'].corr(loan_df['Default'])
# Out:
# 0.08665917723783649

# %%
loan_df['InterestRate'].corr(loan_df['Default'])
# Out:
# 0.13127301527989674

# %%
loan_df['Income'].corr(loan_df['Default'])
# Out:
# -0.09911948445660379

# %%
loan_df['DTIRatio'].corr(loan_df['Default'])
# Out:
# 0.019235981039707927

# %%
loan_df['CreditScore'].corr(loan_df['Default'])
# Out:
# -0.03416649376077059

# %%
loan_df['NumCreditLines'].corr(loan_df['Default'])
# Out:
# 0.028329721809228433

# %%
data = loan_df.drop(columns = ['LoanID','CreditScore','MonthsEmployed','DTIRatio','LoanPurpose'],axis = 1)

# %%
data
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#           Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# ...

# %%
target = data['Default']
features = data.drop('Default',axis = 1)

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#           Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# ...

# %%
marital =  pd.get_dummies(features['MaritalStatus'])

# %%
marital
# Out:
#         Divorced  Married  Single
# 0           True    False   False
# 1          False     True   False
# 2           True    False   False
# 3          False     True   False
# 4           True    False   False
# ...          ...      ...     ...
# 255342     False     True   False
# 255343      True    False   False
# 255344     False     True   False
# 255345     False    False    True
# 255346      True    False   False
#
# [255347 rows x 3 columns]

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#           Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# ...

# %%
 features = pd.concat([features,marital],axis = 1)

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#           Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# ...

# %%
features.isna().sum()
# Out:
# Age               0
# Income            0
# LoanAmount        0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# HasCoSigner       0
# Divorced          0
# Married           0
# Single            0
# dtype: int64

# %%
features.drop('MaritalStatus',axis = 1,inplace = True)

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#           Education EmploymentType HasMortgage HasDependents HasCoSigner  \
# ...

# %%
features['Education'].unique()
# Out:
# array(["Bachelor's", "Master's", 'High School', 'PhD'], dtype=object)

# %%
features['Education'] = features['Education'].map({'High School': 0,"Bachelor's":1,"Master's":2,'PhD':3},)

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#         Education EmploymentType HasMortgage HasDependents HasCoSigner  \
# ...

# %%
features['EmploymentType'].unique()
# Out:
# array(['Full-time', 'Unemployed', 'Self-employed', 'Part-time'],
#       dtype=object)

# %%
features['EmploymentType'] = features['EmploymentType'].map({'Full-time':3,'Self-employed':2,'Part-time':1,'Unemployed':0})

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#         Education  EmploymentType HasMortgage HasDependents HasCoSigner  \
# ...

# %%
features['HasMortgage'] = features['HasMortgage'].map({'Yes': 1,'No': 0})
features['HasDependents'] = features['HasDependents'].map({'Yes':1,'No':0})
features['HasCoSigner'] = features['HasCoSigner'].map({'Yes':1,'No':0})

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#         Education  EmploymentType  HasMortgage  HasDependents  HasCoSigner  \
# ...

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#         Education  EmploymentType  HasMortgage  HasDependents  HasCoSigner  \
# ...

# %%
features[['Married','Single','Divorced']] =  features[['Married','Single','Divorced']].apply(
    lambda x : x.map({False:0,True:1}))

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#         Education  EmploymentType  HasMortgage  HasDependents  HasCoSigner  \
# ...

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#         Education  EmploymentType  HasMortgage  HasDependents  HasCoSigner  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression as LOG

# %%
x_train, x_test, y_train, y_test = train_test_split(
...     features,target, test_size=0.20, random_state=42)

# %%
x_train,y_train
# Out:
# (        Age  Income  LoanAmount  InterestRate  Education  EmploymentType  \
#  137187   18  137576      209136         10.47          0               2
#  230334   47   57194        5970         19.72          0               0
#  19687    26   84328       95065         24.25          2               2
#  106509   53   49795      229582         14.44          1               2
#  242291   49  115450       22072         24.48          1               1
#  ...     ...     ...         ...           ...        ...             ...
#  119879   40  116623      161673         23.44          1               1
#  103694   67   62958      189499          9.29          1               2
#  131932   62   34372       59645          9.72          3               3
#  146867   44  146262      198454          4.31          0               2
#  121958   36   97844      188593         23.14          1               1
#
#          HasMortgage  HasDependents  HasCoSigner  Divorced  Married  Single
# ...

# %%
model = LOG(max_iter = 10000)

# %%
model.fit(features,target)
# Out:
# LogisticRegression(max_iter=10000)

# %%
result = model.predict(x_test)

# %%
result
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,result)
# Out:
# 0.8849618171137654

# %%
confusion_matrix(y_test,result)
# Out:
# array([[45118,    52],
#        [ 5823,    77]], dtype=int64)

# %%
print(classification_report(y_test,result))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     45170
#            1       0.00      0.00      0.00      5900
#
#     accuracy                           0.88     51070
#    macro avg       0.44      0.50      0.47     51070
# weighted avg       0.78      0.88      0.83     51070
# C:\Users\M.Srimanth\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\M.Srimanth\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
data.Default.value_counts()
# Out:
# Default
# 0    225694
# 1     29653
# Name: count, dtype: int64

# %%
features
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 2        46   84208      129188               3         21.17        24
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# ...     ...     ...         ...             ...           ...       ...
# 255342   19   37979      210682               4         14.11        12
# 255343   32   51953      189899               2         11.55        24
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#         Education  EmploymentType  HasMortgage  HasDependents  HasCoSigner  \
# ...

# %%
features.drop(columns = ['NumCreditLines','LoanTerm'],inplace = True)

# %%
features
# Out:
#         Age  Income  LoanAmount  InterestRate  Education  EmploymentType  \
# 0        56   85994       50587         15.23          1               3
# 1        69   50432      124440          4.81          2               3
# 2        46   84208      129188         21.17          2               0
# 3        32   31713       44799          7.07          0               3
# 4        60   20437        9139          6.51          1               0
# ...     ...     ...         ...           ...        ...             ...
# 255342   19   37979      210682         14.11          1               3
# 255343   32   51953      189899         11.55          0               1
# 255344   56   84820      208294          5.29          0               2
# 255345   42   85109       60575         20.90          0               1
# 255346   62   22418       18481          6.73          1               0
#
#         HasMortgage  HasDependents  HasCoSigner  Divorced  Married  Single
# ...

# %%
data['Default'].value_counts()
# Out:
# Default
# 0    225694
# 1     29653
# Name: count, dtype: int64

# %%
default = data[data['Default'] == 1]

# %%
default
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 2        46   84208      129188               3         21.17        24
# 5        25   90298       90448               2         22.72        24
# 8        36   42053       92357               1         23.94        48
# 11       28  149227      139759               3          5.84        36
# 18       19   40718       78515               2         14.00        24
# ...     ...     ...         ...             ...           ...       ...
# 255310   65  111206      112192               3         20.17        36
# 255324   50   34641      108855               4         11.77        24
# 255333   22   45575       43355               1         21.86        12
# 255341   40  129890      116119               3          9.91        24
# 255343   32   51953      189899               2         11.55        24
#
#           Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# ...

# %%
non_default = data[data['Default'] == 0]

# %%
non_default
# Out:
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0        56   85994       50587               4         15.23        36
# 1        69   50432      124440               1          4.81        60
# 3        32   31713       44799               3          7.07        24
# 4        60   20437        9139               4          6.51        48
# 6        38  111188      177025               1         19.11        12
# ...     ...     ...         ...             ...           ...       ...
# 255340   41   61809      119238               2         19.99        36
# 255342   19   37979      210682               4         14.11        12
# 255344   56   84820      208294               3          5.29        60
# 255345   42   85109       60575               1         20.90        48
# 255346   62   22418       18481               2          6.73        12
#
#           Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# ...

# %%
sort_non_default = non_default[:29653]

# %%
sort_non_default
# Out:
#        Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 0       56   85994       50587               4         15.23        36
# 1       69   50432      124440               1          4.81        60
# 3       32   31713       44799               3          7.07        24
# 4       60   20437        9139               4          6.51        48
# 6       38  111188      177025               1         19.11        12
# ...    ...     ...         ...             ...           ...       ...
# 33565   26   37621       18728               1          6.11        12
# 33566   52   45783      125173               2         17.98        36
# 33567   23   89308      248955               1         23.81        60
# 33568   54  134920       26847               2         18.72        24
# 33569   31   79377       36416               1         23.74        12
#
#          Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# ...

# %%
perfect_data = pd.concat([default,sort_non_default],axis = 0)

# %%
perfect_data
# Out:
#        Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 2       46   84208      129188               3         21.17        24
# 5       25   90298       90448               2         22.72        24
# 8       36   42053       92357               1         23.94        48
# 11      28  149227      139759               3          5.84        36
# 18      19   40718       78515               2         14.00        24
# ...    ...     ...         ...             ...           ...       ...
# 33565   26   37621       18728               1          6.11        12
# 33566   52   45783      125173               2         17.98        36
# 33567   23   89308      248955               1         23.81        60
# 33568   54  134920       26847               2         18.72        24
# 33569   31   79377       36416               1         23.74        12
#
#          Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# ...

# %%
perfect_data['Default'].value_counts()
# Out:
# Default
# 1    29653
# 0    29653
# Name: count, dtype: int64

# %%
perfect_target = perfect_data['Default']
perfect_feature = perfect_data.drop(columns = 'Default')

# %%
perfect_target,perfect_feature
# Out:
# (2        1
#  5        1
#  8        1
#  11       1
#  18       1
#          ..
#  33565    0
#  33566    0
#  33567    0
#  33568    0
#  33569    0
#  Name: Default, Length: 59306, dtype: int64,
#         Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
#  2       46   84208      129188               3         21.17        24
#  5       25   90298       90448               2         22.72        24
#  8       36   42053       92357               1         23.94        48
#  11      28  149227      139759               3          5.84        36
#  18      19   40718       78515               2         14.00        24
#  ...    ...     ...         ...             ...           ...       ...
#  33565   26   37621       18728               1          6.11        12
#  33566   52   45783      125173               2         17.98        36
#  33567   23   89308      248955               1         23.81        60
# ...

# %%
Marital = pd.get_dummies(perfect_data['MaritalStatus'],drop_first = True)

# %%
Marital
# Out:
#        Married  Single
# 2        False   False
# 5        False    True
# 8        False   False
# 11       False   False
# 18       False   False
# ...        ...     ...
# 33565     True   False
# 33566    False   False
# 33567     True   False
# 33568    False   False
# 33569    False    True
#
# [59306 rows x 2 columns]

# %%
Marital = Marital.apply(lambda x : x.map({True : 1, False:0}))

# %%
Marital
# Out:
#        Married  Single
# 2            0       0
# 5            0       1
# 8            0       0
# 11           0       0
# 18           0       0
# ...        ...     ...
# 33565        1       0
# 33566        0       0
# 33567        1       0
# 33568        0       0
# 33569        0       1
#
# [59306 rows x 2 columns]

# %%
perfect_feature.drop(columns = 'MaritalStatus',inplace = True)

# %%
perfect_feature = pd.concat([perfect_feature,Marital],axis = 1)

# %%
perfect_feature['Education'].unique()
# Out:
# array(["Master's", 'High School', "Bachelor's", 'PhD'], dtype=object)

# %%
perfect_feature['Education'] = perfect_feature['Education'].map({'High School':0,"Bachelor's":1,"Master's":2,'PhD':3})

# %%
perfect_feature
# Out:
#        Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 2       46   84208      129188               3         21.17        24
# 5       25   90298       90448               2         22.72        24
# 8       36   42053       92357               1         23.94        48
# 11      28  149227      139759               3          5.84        36
# 18      19   40718       78515               2         14.00        24
# ...    ...     ...         ...             ...           ...       ...
# 33565   26   37621       18728               1          6.11        12
# 33566   52   45783      125173               2         17.98        36
# 33567   23   89308      248955               1         23.81        60
# 33568   54  134920       26847               2         18.72        24
# 33569   31   79377       36416               1         23.74        12
#
#        Education EmploymentType HasMortgage HasDependents HasCoSigner  \
# ...

# %%
perfect_feature['EmploymentType'].unique()
# Out:
# array(['Unemployed', 'Self-employed', 'Full-time', 'Part-time'],
#       dtype=object)

# %%
perfect_feature['EmploymentType'] = perfect_feature['EmploymentType'].map({'Unemployed':0,'Part-time':1,'Self-employed':2,'Full-time':3})

# %%
perfect_feature
# Out:
#        Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 2       46   84208      129188               3         21.17        24
# 5       25   90298       90448               2         22.72        24
# 8       36   42053       92357               1         23.94        48
# 11      28  149227      139759               3          5.84        36
# 18      19   40718       78515               2         14.00        24
# ...    ...     ...         ...             ...           ...       ...
# 33565   26   37621       18728               1          6.11        12
# 33566   52   45783      125173               2         17.98        36
# 33567   23   89308      248955               1         23.81        60
# 33568   54  134920       26847               2         18.72        24
# 33569   31   79377       36416               1         23.74        12
#
#        Education  EmploymentType HasMortgage HasDependents HasCoSigner  \
# ...

# %%
perfect_feature[['HasMortgage','HasDependents','HasCoSigner']] = perfect_feature[['HasMortgage','HasDependents','HasCoSigner']].apply(
    lambda x :x.map({'Yes':1,'No':0}))

# %%
perfect_feature
# Out:
#        Age  Income  LoanAmount  NumCreditLines  InterestRate  LoanTerm  \
# 2       46   84208      129188               3         21.17        24
# 5       25   90298       90448               2         22.72        24
# 8       36   42053       92357               1         23.94        48
# 11      28  149227      139759               3          5.84        36
# 18      19   40718       78515               2         14.00        24
# ...    ...     ...         ...             ...           ...       ...
# 33565   26   37621       18728               1          6.11        12
# 33566   52   45783      125173               2         17.98        36
# 33567   23   89308      248955               1         23.81        60
# 33568   54  134920       26847               2         18.72        24
# 33569   31   79377       36416               1         23.74        12
#
#        Education  EmploymentType  HasMortgage  HasDependents  HasCoSigner  \
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split( perfect_feature2, perfect_target, test_size=0.33, random_state=42)

# %%
x_test,y_test
# Out:
# (        Age  Income  LoanAmount  InterestRate  Education  EmploymentType  \
#  225326   31   48621      212332         24.36          1               1
#  16627    58   72357      187626         23.53          1               2
#  73072    63   18273       42294         18.89          0               1
#  20738    18   62987       70901          9.75          3               0
#  161153   43   21038      218103         13.40          2               0
#  ...     ...     ...         ...           ...        ...             ...
#  148833   30   97531       92087         17.50          0               2
#  229041   56  147741       92967         20.87          1               0
#  198161   65  109720       53495          9.18          1               2
#  15276    53  120903      124392          5.74          3               2
#  22494    30  100972      148800         21.26          1               2
#
#          HasMortgage  HasDependents  HasCoSigner  Married  Single
# ...

# %%
model2 = LOG(max_iter = 1000)

# %%
model2.fit(perfect_feature2,perfect_target)
# Out:
# LogisticRegression(max_iter=1000)

# %%
result = model2.predict(x_test)

# %%
result
# Out:
# array([1, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
accuracy_score(y_test,result)
# Out:
# 0.6604670175259312

# %%
confusion_matrix(y_test,result)
# Out:
# array([[6465, 3346],
#        [3274, 6486]], dtype=int64)

# %%
print(classification_report(y_test,result))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66      9811
#            1       0.66      0.66      0.66      9760
#
#     accuracy                           0.66     19571
#    macro avg       0.66      0.66      0.66     19571
# weighted avg       0.66      0.66      0.66     19571

# %%
perfect_feature2 = perfect_feature.drop(columns =['NumCreditLines','LoanTerm'])

# %%
perfect_feature2
# Out:
#        Age  Income  LoanAmount  InterestRate  Education  EmploymentType  \
# 2       46   84208      129188         21.17          2               0
# 5       25   90298       90448         22.72          0               0
# 8       36   42053       92357         23.94          1               2
# 11      28  149227      139759          5.84          3               3
# 18      19   40718       78515         14.00          1               2
# ...    ...     ...         ...           ...        ...             ...
# 33565   26   37621       18728          6.11          3               1
# 33566   52   45783      125173         17.98          3               3
# 33567   23   89308      248955         23.81          3               3
# 33568   54  134920       26847         18.72          3               1
# 33569   31   79377       36416         23.74          1               0
#
#        HasMortgage  HasDependents  HasCoSigner  Married  Single
# ...

# %%
confusion_matrix(y_test,result)
# Out:
# array([[6480, 3331],
#        [3314, 6446]], dtype=int64)

# %%
accuracy_score(y_test,result)
# Out:
# 0.6242910428695518

# %%
confusion_matrix(y_test,result)
# Out:
# array([[6620, 3191],
#        [4162, 5598]], dtype=int64)
